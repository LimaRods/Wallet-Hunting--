# %%
# !pip install python-dotenv
# Out:
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import pandas as  pd
import requests
import numpy as np
import os
from dotenv import load_dotenv

# %%
load_dotenv()
dune_api = os.getenv('DUNE_API')
url = f"https://api.dune.com/api/v1/query/3319571/results?api_key={dune_api}"
response = requests.get(url)
df_vertex = pd.DataFrame(response.json())
data = df_vertex.iloc[-1,-1]
df = pd.DataFrame(data)
order = ['unique_trader', 'platform', 'trading_vol', 'vol_all_platform', 'interactions_count', 'last_interact_date', 'activity','balance_amount_usd']
df = df[order]
# download
df.to_excel("traders_vertex.xlsx", index= False)

df
# Out:
#                                    unique_trader platform   trading_vol  \
# 0     0xaf5e2af64e5926875fa5f3d5e6ac272fc602224e   Vertex  1.090536e+10
# 1     0x5494c260fd71799414d174aa802750efa2dca5dd   Vertex  8.856935e+09
# 2     0x351d1d0ed37f6854bfc36ba24caa529688990f6e   Vertex  2.451329e+09
# 3     0xd604cfa918a7fcf24fd5789483323cdcb37b7fcf   Vertex  4.050209e+08
# 4     0x519e19eac9ead404343c68224dd2a22c5c25f992   Vertex  3.999766e+08
# ...                                          ...      ...           ...
# 1835  0x449f21ae4b9d595aea37c26ca0cb8451fa35d8d3   Vertex  1.008972e+05
# 1836  0xe0171dad0a60c2ff0612655fa57218aa111c10b1   Vertex  1.007075e+05
# 1837  0x2f7552dd5c8f2aa17aea87387a8667c7619f4c0f   Vertex  1.002677e+05
# 1838  0x91a37df1de05293c75ec6007b41214cf15225459   Vertex  1.001159e+05
# 1839  0x88bb50ecafb69dc6cea3c2de93439fcd80a4b787   Vertex  1.000308e+05
#
#      vol_all_platform  interactions_count last_interact_date activity  \
# ...
